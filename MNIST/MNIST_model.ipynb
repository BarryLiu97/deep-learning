# %%
# %matplotlib inline
import os
import os.path as op
import glob
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision as tv
from torchvision import transforms, models

# %%
import sys
sys.path.append("..")
from dataset import MNISTDataset
from model.mnist import BaseModel, Model

# %%
def setup_seed(seed):
    import os
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    torch.manual_seed(seed) # 为CPU设置随机种子
    torch.cuda.manual_seed_all(seed) # 为当前GPU设置随机种子
    torch.cuda.manual_seed_all(seed) # 为所有GPU设置随机种子
    np.random.seed(seed) # # Numpy设置随机种子
    random.seed(seed) # Python设置随机种子
    # torch.backends.cudnn.deterministic = True
    print('Setting up seed finished!')
    
setup_seed(1)
# Out:
# Setting up seed finished!

# %%
# os.makedirs('MNIST/output', exist_ok=True)
# Data
train_set = MNISTDataset(img_dir='', annot_path='train.txt', transform=transforms.ToTensor())
train_loader = DataLoader(dataset=train_set, batch_size=32, shuffle=True)

valid_set = MNISTDataset(img_dir='', annot_path='valid.txt', transform=transforms.ToTensor())
valid_loader = DataLoader(dataset=valid_set, batch_size=32, shuffle=False)

test_set = MNISTDataset(img_dir='', annot_path='test.txt', transform=transforms.ToTensor())
test_loader = DataLoader(dataset=test_set, batch_size=32, shuffle=False)

# %%
len(valid_set)
# Out:
# 12000

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'Using device {device}')
# Out:
# Using device cuda:0

# %%
def train(epoch, model):
    correct = 0
    total = 0
    epoch_loss = 0.
    running_loss = 0.
    if epoch == 0:
        print(model)
    for batch_idx, data in enumerate(train_loader, 0):
        inputs, target = data
        inputs, target = inputs.to(device), target.to(device)  # 转移到cuda，且在同一块显卡上
        optimizer.zero_grad()

        # forward + backard + update
        # outputs = base_model(inputs)
        outputs = model(inputs)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_loss += loss.item()
        if batch_idx % 300 == 299:
            _, predicted = torch.max(outputs.data, dim=1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
            
            print('[%d, %5d] loss: %.3f' % (epoch+1, batch_idx+1, running_loss/2000))
            print(f'Accuracy on train set: {round(100*correct/total, 2)}% [{correct}/{total}]')
            running_loss = 0.0
    return epoch_loss/2000, model

# %%
def valid(epoch, model):
    correct = 0
    total = 0
    print('Validating...')
    model.eval() # 模式转换为测试模式，主要会对BN层和dropout层根据模式进行调整 仍然计算梯度，但是不反向传播
    with torch.no_grad(): # 不会计算梯度，但是对BN层和dropout层并未进行调整 
        for data in valid_loader:
            inputs, target = data
            inputs, target = inputs.to(device), target.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
    print('----------------------------------------------------------------------------')
    print(f'Accuracy on valid set: {round(100*correct/total, 2)}% [{correct}/{total}]')
    print('----------------------------------------------------------------------------')
    print('----------------------------------------------------------------------------')

# %%
def eval(epoch, model):
    correct = 0
    total = 0
    print('Evaluating...')
    model.eval() # 模式转换为测试模式，主要会对BN层和dropout层根据模式进行调整 仍然计算梯度，但是不反向传播
    with torch.no_grad(): # 不会计算梯度，但是对BN层和dropout层并未进行调整
        for data in test_loader:
            inputs, target = data
            inputs, target = inputs.to(device), target.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, dim=1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
    print('----------------------------------------------------------------------------')
    print(f'Accuracy on test set: {round(100*correct/total, 2)}% [{correct}/{total}]')
    print('----------------------------------------------------------------------------')
    print('----------------------------------------------------------------------------')

# %%
model = Model()
model.to(device);

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

epoch_loss = []
for epoch in range(30):
    current_loss, model = train(epoch, model)
    valid(epoch, model)
    epoch_loss.append(current_loss)
eval(epoch, model)
# Out:
# Model(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=1600, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# [1,   300] loss: 0.068
# Accuracy on train set: 96.88% [31/32]
# [1,   600] loss: 0.020
# Accuracy on train set: 98.44% [63/64]
# [1,   900] loss: 0.017
# Accuracy on train set: 96.88% [93/96]
# [1,  1200] loss: 0.014
# Accuracy on train set: 97.66% [125/128]
# [1,  1500] loss: 0.013
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.62% [11715/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [2,   300] loss: 0.012
# Accuracy on train set: 96.88% [31/32]
# [2,   600] loss: 0.011
# Accuracy on train set: 96.88% [62/64]
# [2,   900] loss: 0.009
# Accuracy on train set: 97.92% [94/96]
# [2,  1200] loss: 0.008
# Accuracy on train set: 98.44% [126/128]
# [2,  1500] loss: 0.009
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.23% [11788/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [3,   300] loss: 0.007
# Accuracy on train set: 100.0% [32/32]
# [3,   600] loss: 0.007
# Accuracy on train set: 100.0% [64/64]
# [3,   900] loss: 0.007
# Accuracy on train set: 100.0% [96/96]
# [3,  1200] loss: 0.006
# Accuracy on train set: 100.0% [128/128]
# [3,  1500] loss: 0.006
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.61% [11833/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [4,   300] loss: 0.005
# Accuracy on train set: 96.88% [31/32]
# [4,   600] loss: 0.005
# Accuracy on train set: 98.44% [63/64]
# [4,   900] loss: 0.004
# Accuracy on train set: 98.96% [95/96]
# [4,  1200] loss: 0.004
# Accuracy on train set: 98.44% [126/128]
# [4,  1500] loss: 0.005
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.77% [11852/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [5,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [5,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [5,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [5,  1200] loss: 0.004
# Accuracy on train set: 100.0% [128/128]
# [5,  1500] loss: 0.003
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.85% [11862/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [6,   300] loss: 0.002
# Accuracy on train set: 100.0% [32/32]
# [6,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [6,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [6,  1200] loss: 0.003
# Accuracy on train set: 100.0% [128/128]
# [6,  1500] loss: 0.003
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.88% [11865/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [7,   300] loss: 0.002
# Accuracy on train set: 100.0% [32/32]
# [7,   600] loss: 0.002
# Accuracy on train set: 100.0% [64/64]
# [7,   900] loss: 0.002
# Accuracy on train set: 100.0% [96/96]
# [7,  1200] loss: 0.002
# Accuracy on train set: 100.0% [128/128]
# [7,  1500] loss: 0.002
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.82% [11858/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [8,   300] loss: 0.002
# Accuracy on train set: 96.88% [31/32]
# [8,   600] loss: 0.002
# Accuracy on train set: 98.44% [63/64]
# [8,   900] loss: 0.002
# Accuracy on train set: 98.96% [95/96]
# [8,  1200] loss: 0.002
# Accuracy on train set: 99.22% [127/128]
# [8,  1500] loss: 0.002
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.88% [11865/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [9,   300] loss: 0.001
# Accuracy on train set: 100.0% [32/32]
# [9,   600] loss: 0.001
# Accuracy on train set: 100.0% [64/64]
# [9,   900] loss: 0.001
# Accuracy on train set: 100.0% [96/96]
# [9,  1200] loss: 0.001
# Accuracy on train set: 100.0% [128/128]
# [9,  1500] loss: 0.002
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.94% [11873/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [10,   300] loss: 0.001
# Accuracy on train set: 96.88% [31/32]
# [10,   600] loss: 0.001
# Accuracy on train set: 98.44% [63/64]
# [10,   900] loss: 0.001
# Accuracy on train set: 97.92% [94/96]
# [10,  1200] loss: 0.001
# Accuracy on train set: 98.44% [126/128]
# [10,  1500] loss: 0.001
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.89% [11867/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [11,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [11,   600] loss: 0.001
# Accuracy on train set: 100.0% [64/64]
# [11,   900] loss: 0.001
# Accuracy on train set: 100.0% [96/96]
# [11,  1200] loss: 0.001
# Accuracy on train set: 100.0% [128/128]
# [11,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.89% [11867/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [12,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [12,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [12,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [12,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [12,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.97% [11876/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [13,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [13,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [13,   900] loss: 0.001
# Accuracy on train set: 100.0% [96/96]
# [13,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [13,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.01% [11881/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [14,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [14,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [14,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [14,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [14,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.04% [11885/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [15,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [15,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [15,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [15,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [15,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.08% [11890/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [16,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [16,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [16,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [16,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [16,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.03% [11884/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [17,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [17,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [17,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [17,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [17,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11894/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [18,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [18,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [18,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [18,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [18,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.07% [11888/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [19,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [19,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [19,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [19,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [19,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.07% [11888/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [20,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [20,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [20,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [20,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [20,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.04% [11885/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [21,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [21,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [21,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [21,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [21,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.04% [11885/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [22,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [22,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [22,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [22,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [22,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.05% [11886/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [23,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [23,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [23,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [23,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [23,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.06% [11887/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [24,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [24,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [24,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [24,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [24,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.03% [11883/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [25,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [25,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [25,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [25,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [25,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.04% [11885/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [26,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [26,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [26,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [26,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [26,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.03% [11884/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [27,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [27,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [27,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [27,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [27,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.06% [11887/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [28,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [28,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [28,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [28,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [28,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.04% [11885/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [29,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [29,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [29,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [29,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [29,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.04% [11885/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [30,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [30,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [30,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [30,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [30,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.03% [11884/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# Evaluating...
# ----------------------------------------------------------------------------
# Accuracy on test set: 99.2% [9920/10000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------

# %%
plt.plot(epoch_loss)

# %%
# don't initial parameters
model = Model(init=False)
model.to(device);

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

epoch_loss = []
for epoch in range(30):
    current_loss, model = train(epoch, model)
    valid(epoch, model)
    epoch_loss.append(current_loss)
eval(epoch, model)
# Out:
# Model(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense): Sequential(
#     (0): Linear(in_features=1600, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# [1,   300] loss: 0.062
# Accuracy on train set: 96.88% [31/32]
# [1,   600] loss: 0.019
# Accuracy on train set: 96.88% [62/64]
# [1,   900] loss: 0.015
# Accuracy on train set: 94.79% [91/96]
# [1,  1200] loss: 0.012
# Accuracy on train set: 95.31% [122/128]
# [1,  1500] loss: 0.011
# Accuracy on train set: 95.0% [152/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.37% [11684/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [2,   300] loss: 0.011
# Accuracy on train set: 100.0% [32/32]
# [2,   600] loss: 0.009
# Accuracy on train set: 100.0% [64/64]
# [2,   900] loss: 0.009
# Accuracy on train set: 100.0% [96/96]
# [2,  1200] loss: 0.008
# Accuracy on train set: 100.0% [128/128]
# [2,  1500] loss: 0.007
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.6% [11832/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [3,   300] loss: 0.005
# Accuracy on train set: 100.0% [32/32]
# [3,   600] loss: 0.006
# Accuracy on train set: 98.44% [63/64]
# [3,   900] loss: 0.006
# Accuracy on train set: 97.92% [94/96]
# [3,  1200] loss: 0.006
# Accuracy on train set: 98.44% [126/128]
# [3,  1500] loss: 0.006
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.71% [11845/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [4,   300] loss: 0.004
# Accuracy on train set: 100.0% [32/32]
# [4,   600] loss: 0.005
# Accuracy on train set: 98.44% [63/64]
# [4,   900] loss: 0.004
# Accuracy on train set: 98.96% [95/96]
# [4,  1200] loss: 0.004
# Accuracy on train set: 99.22% [127/128]
# [4,  1500] loss: 0.005
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.72% [11846/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [5,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [5,   600] loss: 0.004
# Accuracy on train set: 100.0% [64/64]
# [5,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [5,  1200] loss: 0.003
# Accuracy on train set: 100.0% [128/128]
# [5,  1500] loss: 0.003
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.97% [11877/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [6,   300] loss: 0.002
# Accuracy on train set: 96.88% [31/32]
# [6,   600] loss: 0.002
# Accuracy on train set: 96.88% [62/64]
# [6,   900] loss: 0.003
# Accuracy on train set: 97.92% [94/96]
# [6,  1200] loss: 0.002
# Accuracy on train set: 98.44% [126/128]
# [6,  1500] loss: 0.003
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.78% [11853/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [7,   300] loss: 0.001
# Accuracy on train set: 100.0% [32/32]
# [7,   600] loss: 0.002
# Accuracy on train set: 100.0% [64/64]
# [7,   900] loss: 0.002
# Accuracy on train set: 100.0% [96/96]
# [7,  1200] loss: 0.002
# Accuracy on train set: 100.0% [128/128]
# [7,  1500] loss: 0.002
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.93% [11872/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [8,   300] loss: 0.002
# Accuracy on train set: 100.0% [32/32]
# [8,   600] loss: 0.001
# Accuracy on train set: 100.0% [64/64]
# [8,   900] loss: 0.002
# Accuracy on train set: 100.0% [96/96]
# [8,  1200] loss: 0.001
# Accuracy on train set: 100.0% [128/128]
# [8,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.07% [11888/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [9,   300] loss: 0.001
# Accuracy on train set: 100.0% [32/32]
# [9,   600] loss: 0.001
# Accuracy on train set: 100.0% [64/64]
# [9,   900] loss: 0.001
# Accuracy on train set: 100.0% [96/96]
# [9,  1200] loss: 0.001
# Accuracy on train set: 100.0% [128/128]
# [9,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.98% [11878/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [10,   300] loss: 0.001
# Accuracy on train set: 100.0% [32/32]
# [10,   600] loss: 0.001
# Accuracy on train set: 100.0% [64/64]
# [10,   900] loss: 0.001
# Accuracy on train set: 100.0% [96/96]
# [10,  1200] loss: 0.001
# Accuracy on train set: 100.0% [128/128]
# [10,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.92% [11871/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [11,   300] loss: 0.001
# Accuracy on train set: 100.0% [32/32]
# [11,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [11,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [11,  1200] loss: 0.001
# Accuracy on train set: 100.0% [128/128]
# [11,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.1% [11892/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [12,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [12,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [12,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [12,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [12,  1500] loss: 0.001
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.01% [11881/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [13,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [13,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [13,   900] loss: 0.001
# Accuracy on train set: 100.0% [96/96]
# [13,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [13,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.1% [11892/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [14,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [14,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [14,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [14,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [14,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11895/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [15,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [15,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [15,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [15,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [15,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.08% [11890/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [16,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [16,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [16,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [16,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [16,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.14% [11897/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [17,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [17,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [17,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [17,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [17,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.14% [11897/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [18,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [18,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [18,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [18,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [18,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.1% [11892/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [19,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [19,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [19,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [19,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [19,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11894/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [20,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [20,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [20,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [20,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [20,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.14% [11897/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [21,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [21,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [21,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [21,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [21,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.11% [11893/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [22,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [22,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [22,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [22,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [22,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.13% [11896/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [23,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [23,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [23,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [23,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [23,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.17% [11900/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [24,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [24,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [24,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [24,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [24,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11895/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [25,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [25,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [25,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [25,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [25,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11895/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [26,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [26,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [26,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [26,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [26,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.16% [11899/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [27,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [27,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [27,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [27,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [27,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11895/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [28,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [28,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [28,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [28,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [28,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11894/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [29,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [29,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [29,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [29,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [29,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11895/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [30,   300] loss: 0.000
# Accuracy on train set: 100.0% [32/32]
# [30,   600] loss: 0.000
# Accuracy on train set: 100.0% [64/64]
# [30,   900] loss: 0.000
# Accuracy on train set: 100.0% [96/96]
# [30,  1200] loss: 0.000
# Accuracy on train set: 100.0% [128/128]
# [30,  1500] loss: 0.000
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 99.12% [11894/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# Evaluating...
# ----------------------------------------------------------------------------
# Accuracy on test set: 99.25% [9925/10000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------

# %%
plt.plot(epoch_loss)

# %%
base_model = BaseModel()
base_model.to(device);

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(base_model.parameters(), lr=0.01, momentum=0.5)

epoch_loss = []
for epoch in range(30):
    current_loss, base_model = train(epoch, base_model)
    valid(epoch, base_model)
    epoch_loss.append(current_loss)
eval(epoch, base_model)
# Out:
# BaseModel(
#   (conv1): Conv2d(3, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc): Linear(in_features=320, out_features=10, bias=True)
# )
# [1,   300] loss: 0.150
# Accuracy on train set: 84.38% [27/32]
# [1,   600] loss: 0.041
# Accuracy on train set: 92.19% [59/64]
# [1,   900] loss: 0.028
# Accuracy on train set: 94.79% [91/96]
# [1,  1200] loss: 0.025
# Accuracy on train set: 95.31% [122/128]
# [1,  1500] loss: 0.020
# Accuracy on train set: 96.25% [154/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 94.25% [11310/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [2,   300] loss: 0.018
# Accuracy on train set: 96.88% [31/32]
# [2,   600] loss: 0.017
# Accuracy on train set: 93.75% [60/64]
# [2,   900] loss: 0.016
# Accuracy on train set: 94.79% [91/96]
# [2,  1200] loss: 0.015
# Accuracy on train set: 93.75% [120/128]
# [2,  1500] loss: 0.014
# Accuracy on train set: 95.0% [152/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.12% [11654/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [3,   300] loss: 0.013
# Accuracy on train set: 96.88% [31/32]
# [3,   600] loss: 0.012
# Accuracy on train set: 98.44% [63/64]
# [3,   900] loss: 0.014
# Accuracy on train set: 97.92% [94/96]
# [3,  1200] loss: 0.011
# Accuracy on train set: 96.88% [124/128]
# [3,  1500] loss: 0.012
# Accuracy on train set: 97.5% [156/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.46% [11695/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [4,   300] loss: 0.011
# Accuracy on train set: 93.75% [30/32]
# [4,   600] loss: 0.013
# Accuracy on train set: 95.31% [61/64]
# [4,   900] loss: 0.009
# Accuracy on train set: 96.88% [93/96]
# [4,  1200] loss: 0.010
# Accuracy on train set: 96.88% [124/128]
# [4,  1500] loss: 0.010
# Accuracy on train set: 97.5% [156/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.69% [11723/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [5,   300] loss: 0.010
# Accuracy on train set: 96.88% [31/32]
# [5,   600] loss: 0.010
# Accuracy on train set: 98.44% [63/64]
# [5,   900] loss: 0.009
# Accuracy on train set: 97.92% [94/96]
# [5,  1200] loss: 0.010
# Accuracy on train set: 98.44% [126/128]
# [5,  1500] loss: 0.008
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.77% [11732/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [6,   300] loss: 0.009
# Accuracy on train set: 93.75% [30/32]
# [6,   600] loss: 0.008
# Accuracy on train set: 96.88% [62/64]
# [6,   900] loss: 0.008
# Accuracy on train set: 97.92% [94/96]
# [6,  1200] loss: 0.008
# Accuracy on train set: 97.66% [125/128]
# [6,  1500] loss: 0.009
# Accuracy on train set: 97.5% [156/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.8% [11736/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [7,   300] loss: 0.008
# Accuracy on train set: 100.0% [32/32]
# [7,   600] loss: 0.007
# Accuracy on train set: 100.0% [64/64]
# [7,   900] loss: 0.007
# Accuracy on train set: 98.96% [95/96]
# [7,  1200] loss: 0.009
# Accuracy on train set: 98.44% [126/128]
# [7,  1500] loss: 0.008
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 97.7% [11724/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [8,   300] loss: 0.007
# Accuracy on train set: 96.88% [31/32]
# [8,   600] loss: 0.008
# Accuracy on train set: 98.44% [63/64]
# [8,   900] loss: 0.007
# Accuracy on train set: 98.96% [95/96]
# [8,  1200] loss: 0.008
# Accuracy on train set: 99.22% [127/128]
# [8,  1500] loss: 0.007
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.13% [11776/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [9,   300] loss: 0.006
# Accuracy on train set: 96.88% [31/32]
# [9,   600] loss: 0.007
# Accuracy on train set: 96.88% [62/64]
# [9,   900] loss: 0.007
# Accuracy on train set: 97.92% [94/96]
# [9,  1200] loss: 0.007
# Accuracy on train set: 98.44% [126/128]
# [9,  1500] loss: 0.007
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.08% [11770/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [10,   300] loss: 0.007
# Accuracy on train set: 100.0% [32/32]
# [10,   600] loss: 0.007
# Accuracy on train set: 100.0% [64/64]
# [10,   900] loss: 0.005
# Accuracy on train set: 100.0% [96/96]
# [10,  1200] loss: 0.007
# Accuracy on train set: 99.22% [127/128]
# [10,  1500] loss: 0.007
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.12% [11774/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [11,   300] loss: 0.006
# Accuracy on train set: 100.0% [32/32]
# [11,   600] loss: 0.006
# Accuracy on train set: 100.0% [64/64]
# [11,   900] loss: 0.006
# Accuracy on train set: 100.0% [96/96]
# [11,  1200] loss: 0.005
# Accuracy on train set: 100.0% [128/128]
# [11,  1500] loss: 0.007
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.17% [11781/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [12,   300] loss: 0.006
# Accuracy on train set: 93.75% [30/32]
# [12,   600] loss: 0.005
# Accuracy on train set: 95.31% [61/64]
# [12,   900] loss: 0.005
# Accuracy on train set: 96.88% [93/96]
# [12,  1200] loss: 0.007
# Accuracy on train set: 97.66% [125/128]
# [12,  1500] loss: 0.005
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.18% [11782/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [13,   300] loss: 0.005
# Accuracy on train set: 100.0% [32/32]
# [13,   600] loss: 0.005
# Accuracy on train set: 100.0% [64/64]
# [13,   900] loss: 0.006
# Accuracy on train set: 100.0% [96/96]
# [13,  1200] loss: 0.006
# Accuracy on train set: 100.0% [128/128]
# [13,  1500] loss: 0.006
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.23% [11788/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [14,   300] loss: 0.004
# Accuracy on train set: 100.0% [32/32]
# [14,   600] loss: 0.005
# Accuracy on train set: 100.0% [64/64]
# [14,   900] loss: 0.005
# Accuracy on train set: 100.0% [96/96]
# [14,  1200] loss: 0.006
# Accuracy on train set: 100.0% [128/128]
# [14,  1500] loss: 0.006
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.28% [11794/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [15,   300] loss: 0.004
# Accuracy on train set: 93.75% [30/32]
# [15,   600] loss: 0.005
# Accuracy on train set: 95.31% [61/64]
# [15,   900] loss: 0.005
# Accuracy on train set: 96.88% [93/96]
# [15,  1200] loss: 0.005
# Accuracy on train set: 97.66% [125/128]
# [15,  1500] loss: 0.006
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.27% [11792/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [16,   300] loss: 0.004
# Accuracy on train set: 100.0% [32/32]
# [16,   600] loss: 0.004
# Accuracy on train set: 98.44% [63/64]
# [16,   900] loss: 0.005
# Accuracy on train set: 98.96% [95/96]
# [16,  1200] loss: 0.005
# Accuracy on train set: 98.44% [126/128]
# [16,  1500] loss: 0.005
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.38% [11805/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [17,   300] loss: 0.004
# Accuracy on train set: 96.88% [31/32]
# [17,   600] loss: 0.004
# Accuracy on train set: 98.44% [63/64]
# [17,   900] loss: 0.005
# Accuracy on train set: 98.96% [95/96]
# [17,  1200] loss: 0.004
# Accuracy on train set: 98.44% [126/128]
# [17,  1500] loss: 0.005
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.42% [11810/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [18,   300] loss: 0.004
# Accuracy on train set: 100.0% [32/32]
# [18,   600] loss: 0.004
# Accuracy on train set: 100.0% [64/64]
# [18,   900] loss: 0.005
# Accuracy on train set: 100.0% [96/96]
# [18,  1200] loss: 0.004
# Accuracy on train set: 100.0% [128/128]
# [18,  1500] loss: 0.005
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.33% [11800/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [19,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [19,   600] loss: 0.004
# Accuracy on train set: 98.44% [63/64]
# [19,   900] loss: 0.005
# Accuracy on train set: 97.92% [94/96]
# [19,  1200] loss: 0.004
# Accuracy on train set: 98.44% [126/128]
# [19,  1500] loss: 0.004
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.51% [11821/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [20,   300] loss: 0.004
# Accuracy on train set: 96.88% [31/32]
# [20,   600] loss: 0.004
# Accuracy on train set: 98.44% [63/64]
# [20,   900] loss: 0.004
# Accuracy on train set: 98.96% [95/96]
# [20,  1200] loss: 0.004
# Accuracy on train set: 99.22% [127/128]
# [20,  1500] loss: 0.004
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.39% [11807/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [21,   300] loss: 0.004
# Accuracy on train set: 96.88% [31/32]
# [21,   600] loss: 0.003
# Accuracy on train set: 98.44% [63/64]
# [21,   900] loss: 0.004
# Accuracy on train set: 97.92% [94/96]
# [21,  1200] loss: 0.004
# Accuracy on train set: 98.44% [126/128]
# [21,  1500] loss: 0.004
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.25% [11790/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [22,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [22,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [22,   900] loss: 0.004
# Accuracy on train set: 98.96% [95/96]
# [22,  1200] loss: 0.004
# Accuracy on train set: 99.22% [127/128]
# [22,  1500] loss: 0.004
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.26% [11791/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [23,   300] loss: 0.003
# Accuracy on train set: 93.75% [30/32]
# [23,   600] loss: 0.004
# Accuracy on train set: 95.31% [61/64]
# [23,   900] loss: 0.004
# Accuracy on train set: 96.88% [93/96]
# [23,  1200] loss: 0.003
# Accuracy on train set: 97.66% [125/128]
# [23,  1500] loss: 0.003
# Accuracy on train set: 98.12% [157/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.47% [11817/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [24,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [24,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [24,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [24,  1200] loss: 0.004
# Accuracy on train set: 100.0% [128/128]
# [24,  1500] loss: 0.004
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.3% [11796/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [25,   300] loss: 0.004
# Accuracy on train set: 100.0% [32/32]
# [25,   600] loss: 0.003
# Accuracy on train set: 98.44% [63/64]
# [25,   900] loss: 0.003
# Accuracy on train set: 98.96% [95/96]
# [25,  1200] loss: 0.003
# Accuracy on train set: 99.22% [127/128]
# [25,  1500] loss: 0.003
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.44% [11813/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [26,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [26,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [26,   900] loss: 0.004
# Accuracy on train set: 100.0% [96/96]
# [26,  1200] loss: 0.003
# Accuracy on train set: 100.0% [128/128]
# [26,  1500] loss: 0.003
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.29% [11795/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [27,   300] loss: 0.003
# Accuracy on train set: 96.88% [31/32]
# [27,   600] loss: 0.002
# Accuracy on train set: 98.44% [63/64]
# [27,   900] loss: 0.003
# Accuracy on train set: 97.92% [94/96]
# [27,  1200] loss: 0.003
# Accuracy on train set: 98.44% [126/128]
# [27,  1500] loss: 0.003
# Accuracy on train set: 98.75% [158/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.3% [11796/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [28,   300] loss: 0.003
# Accuracy on train set: 100.0% [32/32]
# [28,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [28,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [28,  1200] loss: 0.002
# Accuracy on train set: 99.22% [127/128]
# [28,  1500] loss: 0.003
# Accuracy on train set: 99.38% [159/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.41% [11809/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [29,   300] loss: 0.002
# Accuracy on train set: 100.0% [32/32]
# [29,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [29,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [29,  1200] loss: 0.003
# Accuracy on train set: 100.0% [128/128]
# [29,  1500] loss: 0.003
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.44% [11813/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# [30,   300] loss: 0.002
# Accuracy on train set: 100.0% [32/32]
# [30,   600] loss: 0.003
# Accuracy on train set: 100.0% [64/64]
# [30,   900] loss: 0.003
# Accuracy on train set: 100.0% [96/96]
# [30,  1200] loss: 0.003
# Accuracy on train set: 100.0% [128/128]
# [30,  1500] loss: 0.003
# Accuracy on train set: 100.0% [160/160]
# Validating...
# ----------------------------------------------------------------------------
# Accuracy on valid set: 98.46% [11815/12000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# Evaluating...
# ----------------------------------------------------------------------------
# Accuracy on test set: 98.65% [9865/10000]
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------

# %%
plt.plot(epoch_loss)
